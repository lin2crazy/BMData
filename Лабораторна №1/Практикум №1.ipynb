# %% [markdown]
# Предмет: Обробка та аналіз БМД<br>
# Студент: Збаровський Дмитро<br>
# Група: БС-81

# %%
import pandas as pd

# %%
new_df = pd.DataFrame(
{
    "Car": ["BMW M5 F90","BMW M5 e60","AUDI RS6 C7","Mercedes-AMG C63 S"],
    "Years of production": ["since 2017","2005-2010","since 2013","since 2015"],
    "Engine": ["V8","V10","V8","V8"],
    "Power": [600,507,580,510],
    "Torque": [750,520,700,700],
    "Price": [117900,90000,80000,135000]
})

new_df
# Out:
#                   Car Years of production Engine  Power  Torque   Price
# 0          BMW M5 F90          since 2017     V8    600     750  117900
# 1          BMW M5 e60           2005-2010    V10    507     520   90000
# 2         AUDI RS6 C7          since 2013     V8    580     700   80000
# 3  Mercedes-AMG C63 S          since 2015     V8    510     700  135000

# %%
path = "D:/data/data.csv"
data = pd.read_csv(path, encoding = 'utf-8')

print(type(data))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
import os

print("The directory we are working in is: {}".format(os.getcwd()))
# Out:
# The directory we are working in is: C:\Users\User\AppData\Local\Programs\Python\Python38-32\Scripts

# %%
data = pd.read_csv(path)

print(type(data))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
data
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
# ...

# %%
data.shape
# Out:
# (11914, 16)

# %%
data.tail(5)
# Out:
#           Make   Model  Year                Engine Fuel Type  Engine HP  \
# 11909    Acura     ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura     ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura     ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura     ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln  Zephyr  2006                regular unleaded      221.0
#
#        Engine Cylinders Transmission Type      Driven_Wheels  Number of Doors  \
# 11909               6.0         AUTOMATIC    all wheel drive              4.0
# 11910               6.0         AUTOMATIC    all wheel drive              4.0
# 11911               6.0         AUTOMATIC    all wheel drive              4.0
# 11912               6.0         AUTOMATIC    all wheel drive              4.0
# 11913               6.0         AUTOMATIC  front wheel drive              4.0
#
# ...

# %%
data.head(5)
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# ...

# %%
data.dtypes
# Out:
# Make                  object
# Model                 object
# Year                   int64
# Engine Fuel Type      object
# Engine HP            float64
# Engine Cylinders     float64
# Transmission Type     object
# Driven_Wheels         object
# Number of Doors      float64
# Market Category       object
# Vehicle Size          object
# Vehicle Style         object
# highway MPG            int64
# city mpg               int64
# Popularity             int64
# MSRP                   int64
# dtype: object

# %%
data.describe()
# Out:
#                Year    Engine HP  Engine Cylinders  Number of Doors  \
# count  11914.000000  11845.00000      11884.000000     11908.000000
# mean    2010.384338    249.38607          5.628829         3.436093
# std        7.579740    109.19187          1.780559         0.881315
# min     1990.000000     55.00000          0.000000         2.000000
# 25%     2007.000000    170.00000          4.000000         2.000000
# 50%     2015.000000    227.00000          6.000000         4.000000
# 75%     2016.000000    300.00000          6.000000         4.000000
# max     2017.000000   1001.00000         16.000000         4.000000
#
#         highway MPG      city mpg    Popularity          MSRP
# count  11914.000000  11914.000000  11914.000000  1.191400e+04
# mean      26.637485     19.733255   1554.911197  4.059474e+04
# std        8.863001      8.987798   1441.855347  6.010910e+04
# min       12.000000      7.000000      2.000000  2.000000e+03
# ...

# %%
data['Year'].describe()
# Out:
# count    11914.000000
# mean      2010.384338
# std          7.579740
# min       1990.000000
# 25%       2007.000000
# 50%       2015.000000
# 75%       2016.000000
# max       2017.000000
# Name: Year, dtype: float64

# %%
data['Engine HP'].describe()
# Out:
# count    11845.00000
# mean       249.38607
# std        109.19187
# min         55.00000
# 25%        170.00000
# 50%        227.00000
# 75%        300.00000
# max       1001.00000
# Name: Engine HP, dtype: float64

# %%
cut_data = data.iloc[0:10, :]
cut_data
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
# 5  BMW    1 Series  2012  premium unleaded (required)      230.0
# 6  BMW    1 Series  2012  premium unleaded (required)      300.0
# 7  BMW    1 Series  2012  premium unleaded (required)      300.0
# 8  BMW    1 Series  2012  premium unleaded (required)      230.0
# 9  BMW    1 Series  2013  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# ...

# %%
new_data = ["gr1", "gr1","gr1","gr1","gr1","gr2","gr2","gr2","gr2","gr2"]
cut_data.insert(1, "Group", new_data)
cut_data
# Out:
#   Make Group       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW   gr1  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW   gr1    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW   gr1    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW   gr1    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW   gr1    1 Series  2011  premium unleaded (required)      230.0
# 5  BMW   gr2    1 Series  2012  premium unleaded (required)      230.0
# 6  BMW   gr2    1 Series  2012  premium unleaded (required)      300.0
# 7  BMW   gr2    1 Series  2012  premium unleaded (required)      300.0
# 8  BMW   gr2    1 Series  2012  premium unleaded (required)      230.0
# 9  BMW   gr2    1 Series  2013  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# ...

# %%
cut_data.groupby('Group').describe()
# Out:
#        Year                                                            \
#       count    mean       std     min     25%     50%     75%     max
# Group
# gr1     5.0  2011.0  0.000000  2011.0  2011.0  2011.0  2011.0  2011.0
# gr2     5.0  2012.2  0.447214  2012.0  2012.0  2012.0  2012.0  2013.0
#
#       Engine HP         ... Popularity          MSRP                        \
#           count   mean  ...        75%     max count     mean          std
# Group                   ...
# gr1         5.0  279.0  ...     3916.0  3916.0   5.0  37417.0  6316.175267
# gr2         5.0  258.0  ...     3916.0  3916.0   5.0  37740.0  4654.352801
#
#
#            min      25%      50%      75%      max
# Group
# gr1    29450.0  34500.0  36350.0  40650.0  46135.0
# gr2    31200.0  36900.0  37200.0  39300.0  44100.0
#
# [2 rows x 64 columns]

# %%
cut_data.to_csv("output_cut.csv", encoding = 'utf8')
data.describe().to_csv("output.csv", encoding = 'utf-8')
