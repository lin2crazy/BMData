# %% [markdown]
# Try to recreate the plots below (don't worry about color schemes, just the plot itself.

# %% [markdown]
# ## The Data
#
# We will be working with a famous titanic data set for these exercises.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sns.set_style('whitegrid')

# %% [markdown]
# Download titanic data from build-in data frames

# %%
# CODE HERE
titanic = sns.load_dataset('titanic')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# # Exercises
#
# ** Recreate the plots below using the titanic dataframe. There are very few hints since most of the plots can be done with just one or two lines of code and a hint would basically give away the solution. Keep careful attention to the x and y labels for hints.**
#
# ** *Note! In order to not lose the plot image, make sure you don't code in the cell that is directly above the plot, there is an extra cell above that one which won't overwrite that plot!* **

# %%
# CODE HERE
# REPLICATE EXERCISE PLOT IMAGE BELOW
# BE CAREFUL NOT TO OVERWRITE CELL BELOW
# THAT WOULD REMOVE THE EXERCISE PLOT IMAGE!
sns.jointplot(x = 'fare', y = 'age', data = titanic, kind = 'kde')

# %%
# CODE HERE
# REPLICATE EXERCISE PLOT IMAGE BELOW
# BE CAREFUL NOT TO OVERWRITE CELL BELOW
# THAT WOULD REMOVE THE EXERCISE PLOT IMAGE!
sns.distplot(titanic['fare'], kde = False, bins = 20)

# %%
# CODE HERE
# REPLICATE EXERCISE PLOT IMAGE BELOW
# BE CAREFUL NOT TO OVERWRITE CELL BELOW
# THAT WOULD REMOVE THE EXERCISE PLOT IMAGE!
sns.boxplot(x = 'pclass', y = 'age', data = titanic)

# %%
# CODE HERE
# REPLICATE EXERCISE PLOT IMAGE BELOW
# BE CAREFUL NOT TO OVERWRITE CELL BELOW
# THAT WOULD REMOVE THE EXERCISE PLOT IMAGE!
sns.barplot(x = 'class', y = 'fare', hue = 'alone', data = titanic)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-77fb5ee9f82b> in <module>
#       3 # BE CAREFUL NOT TO OVERWRITE CELL BELOW
#       4 # THAT WOULD REMOVE THE EXERCISE PLOT IMAGE!
# ----> 5 sns.barplot(x = 'class', y = 'fare', hue = 'alone', data = titanic)
#
# c:\users\user\appdata\local\programs\python\python38-32\lib\site-packages\seaborn\categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3145             ax=None, **kwargs):
#    3146
# -> 3147     plotter = _BarPlotter(x, y, hue, data, order, hue_order,
#    3148                           estimator, ci, n_boot, units, seed,
#    3149                           orient, color, palette, saturation,
#
# c:\users\user\appdata\local\programs\python\python38-32\lib\site-packages\seaborn\categorical.py in __init__(self, x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge)
#    1615                                  order, hue_order, units)
#    1616         self.establish_colors(color, palette, saturation)
# -> 1617         self.estimate_statistic(estimator, ci, n_boot, seed)
#    1618
#    1619         self.dodge = dodge
#
# c:\users\user\appdata\local\programs\python\python38-32\lib\site-packages\seaborn\categorical.py in estimate_statistic(self, estimator, ci, n_boot, seed)
#    1565                         else:
#    1566
# -> 1567                             boots = bootstrap(stat_data, func=estimator,
#    1568                                               n_boot=n_boot,
#    1569                                               units=unit_data,
#
# c:\users\user\appdata\local\programs\python\python38-32\lib\site-packages\seaborn\algorithms.py in bootstrap(*args, **kwargs)
#      83     for i in range(int(n_boot)):
#      84         resampler = integers(0, n, n)
# ---> 85         sample = [a.take(resampler, axis=0) for a in args]
#      86         boot_dist.append(f(*sample, **func_kwargs))
#      87     return np.array(boot_dist)
#
# c:\users\user\appdata\local\programs\python\python38-32\lib\site-packages\seaborn\algorithms.py in <listcomp>(.0)
#      83     for i in range(int(n_boot)):
#      84         resampler = integers(0, n, n)
# ---> 85         sample = [a.take(resampler, axis=0) for a in args]
#      86         boot_dist.append(f(*sample, **func_kwargs))
#      87     return np.array(boot_dist)
#
# TypeError: Cannot cast array data from dtype('int64') to dtype('int32') according to the rule 'safe'

# %%
# CODE HERE
# REPLICATE EXERCISE PLOT IMAGE BELOW
# BE CAREFUL NOT TO OVERWRITE CELL BELOW
# THAT WOULD REMOVE THE EXERCISE PLOT IMAGE!
sns.barplot(x = 'alone', y = 'age', data = titanic)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-2de59ff53883> in <module>
#       3 # BE CAREFUL NOT TO OVERWRITE CELL BELOW
#       4 # THAT WOULD REMOVE THE EXERCISE PLOT IMAGE!
# ----> 5 sns.barplot(x = 'alone', y = 'age', data = titanic)
#
# c:\users\user\appdata\local\programs\python\python38-32\lib\site-packages\seaborn\categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3145             ax=None, **kwargs):
#    3146
# -> 3147     plotter = _BarPlotter(x, y, hue, data, order, hue_order,
#    3148                           estimator, ci, n_boot, units, seed,
#    3149                           orient, color, palette, saturation,
#
# c:\users\user\appdata\local\programs\python\python38-32\lib\site-packages\seaborn\categorical.py in __init__(self, x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge)
#    1615                                  order, hue_order, units)
#    1616         self.establish_colors(color, palette, saturation)
# -> 1617         self.estimate_statistic(estimator, ci, n_boot, seed)
#    1618
#    1619         self.dodge = dodge
#
# c:\users\user\appdata\local\programs\python\python38-32\lib\site-packages\seaborn\categorical.py in estimate_statistic(self, estimator, ci, n_boot, seed)
#    1514                     else:
#    1515
# -> 1516                         boots = bootstrap(stat_data, func=estimator,
#    1517                                           n_boot=n_boot,
#    1518                                           units=unit_data,
#
# c:\users\user\appdata\local\programs\python\python38-32\lib\site-packages\seaborn\algorithms.py in bootstrap(*args, **kwargs)
#      83     for i in range(int(n_boot)):
#      84         resampler = integers(0, n, n)
# ---> 85         sample = [a.take(resampler, axis=0) for a in args]
#      86         boot_dist.append(f(*sample, **func_kwargs))
#      87     return np.array(boot_dist)
#
# c:\users\user\appdata\local\programs\python\python38-32\lib\site-packages\seaborn\algorithms.py in <listcomp>(.0)
#      83     for i in range(int(n_boot)):
#      84         resampler = integers(0, n, n)
# ---> 85         sample = [a.take(resampler, axis=0) for a in args]
#      86         boot_dist.append(f(*sample, **func_kwargs))
#      87     return np.array(boot_dist)
#
# TypeError: Cannot cast array data from dtype('int64') to dtype('int32') according to the rule 'safe'

# %%
# CODE HERE
# REPLICATE EXERCISE PLOT IMAGE BELOW
# BE CAREFUL NOT TO OVERWRITE CELL BELOW
# THAT WOULD REMOVE THE EXERCISE PLOT IMAGE!
sns.stripplot(data = titanic, x = 'alive', y = 'age', hue = 'class', dodge = True)

# %%
# CODE HERE
# REPLICATE EXERCISE PLOT IMAGE BELOW
# BE CAREFUL NOT TO OVERWRITE CELL BELOW
# THAT WOULD REMOVE THE EXERCISE PLOT IMAGE!
sns.heatmap(data=titanic.corr())

# %%
# CODE HERE
# REPLICATE EXERCISE PLOT IMAGE BELOW
# BE CAREFUL NOT TO OVERWRITE CELL BELOW
# THAT WOULD REMOVE THE EXERCISE PLOT IMAGE!
g = sns.FacetGrid(titanic, col="sex")
g = g.map(plt.hist, 'fare').add_legend()

# %%
g = sns.FacetGrid(data = titanic, col = 'class',  row = 'sex')
g = g.map(plt.scatter, 'age', 'fare')

# %% [markdown]
# Build three customized various graphs using knowledge from:
# http://seaborn.pydata.org/tutorial/aesthetics.html

# %%
import numpy as np

# %%
def plot(flip=1):
    x = np.linspace(0, 14, 100)
    for i in range(1, 6):
        plt.plot(x, 2*x + x**3 - (6*x / i))

# %%
f = plt.figure(figsize=(20, 20))
gs = f.add_gridspec(2, 2)

with sns.axes_style('darkgrid', {"axes.facecolor": ".6"}):
    ax = f.add_subplot(gs[0, 0])
    plot()

with sns.axes_style('whitegrid'):
    ax = f.add_subplot(gs[0, 1])
    plot()

with sns.axes_style('ticks', {"axes.facecolor": ".8"}):
    sns.set_context("poster")
    ax = f.add_subplot(gs[1, 0])
    plot()

f.tight_layout()
